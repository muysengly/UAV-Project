# %%
# Import libraries
import pants
import math
import random
import matplotlib.pyplot as plt

# %%
# Define parameters
n = 20  # number of cities

# Generate random cities and coordinates
cities = [(
    random.uniform(0, 1),
    random.uniform(0, 1)
) for i in range(n)]


# Define the length function as the euclidean distance between two cities
def euclidean(a, b):
    return math.sqrt(pow(a[1] - b[1], 2) + pow(a[0] - b[0], 2))


# Create the world with the cities and the length function
world = pants.World(cities, euclidean)

# Create the solver with some default parameters
solver = pants.Solver()

# Solve the world and get the best solution
solution = solver.solve(world)

# Print the best tour and its length
print("Best tour:", solution.tour)
print("Best length:", solution.distance)
# Out:
# Best tour: [(0.8788331822689933, 0.8200964291733777), (0.9490032325499225, 0.8080419989525454), (0.8408031263678215, 0.44100035669788573), (0.7322127893934454, 0.44918671453948533), (0.7285004753444354, 0.39311331497295976), (0.8881785002679938, 0.23107440526445244), (0.787445413567486, 0.08544235263221067), (0.7273492947713015, 0.10684462218215962), (0.6300365221121654, 0.034863796428473925), (0.6139662954462947, 0.2686339105740042), (0.4692840742253671, 0.26457895782127183), (0.4756012883838914, 0.18971059272793744), (0.2980104258162384, 0.02779430737439037), (0.2031569233897883, 0.19334408668911118), (0.10051341052565221, 0.1288532024523108), (0.26543105962347535, 0.7573147598225508), (0.10196996421402538, 0.9407634281028111), (0.5148191011515582, 0.9340106092065252), (0.5182024262255965, 0.981149100705075), (0.5471564580196512, 0.7325588120927807)]
# Best length: 4.163811656690288

# %%
# Plot the best tour
plt.figure()

plt.scatter([city[0] for city in cities], [city[1] for city in cities], color='blue')  # plot the cities as blue dots

for i in range(n - 1):
    plt.plot([solution.tour[i][0], solution.tour[i + 1][0]], [solution.tour[i][1], solution.tour[i + 1][1]],
             color='black')  # plot the edges between consecutive cities as black lines

plt.plot([solution.tour[n - 1][0], solution.tour[0][0]], [solution.tour[n - 1][1], solution.tour[0][1]],
         color='black')  # plot the edge from the last city to the first city as a black line

plt.title(f"Best tour with length {solution.distance}")  # add a title with the best length

plt.show()  # show the plot
