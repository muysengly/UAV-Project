# %% [markdown]
# pip install stable-baselines3[extra]
#
# pip install protobuf==3.20.1

# %%
import gym
from stable_baselines3 import DQN

# env = gym.make("CartPole-v1", render_mode="human")
env = gym.make("CartPole-v1", render_mode="rgb_array")

# %%
model = DQN("MlpPolicy", env, verbose=1)
model.learn(100000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 6618     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 53       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 7228     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 123      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 8206     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 230      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 8686     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 313      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 8673     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 382      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 8857     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 461      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 8905     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 517      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 8917     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 598      |
# ----------------------------------
# C:\Users\ains_sengly\anaconda3\envs\python310\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\ains_sengly\anaconda3\envs\python310\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 9136     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 695      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 9269     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 835      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 9277     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 910      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 9352     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 9350     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 9290     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 9400     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1289     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 9413     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 9436     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1464     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 9458     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 9479     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1670     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 9507     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 9517     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 9587     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1948     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 9599     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 9581     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2129     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 9608     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 9616     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2310     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 9605     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 9610     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 9601     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 9617     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 9604     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 9625     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 9583     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 9605     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2913     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 9613     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 9601     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 9610     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 9624     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 9620     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 9618     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 9608     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3472     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 9631     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3596     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 9624     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 9628     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 9624     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 9623     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3930     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 9614     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 9643     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4112     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 9647     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4220     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 9671     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4366     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 9672     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 9689     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4568     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 9678     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 9685     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 9688     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4839     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 9689     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 9679     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5009     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 9696     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 9690     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5189     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 9695     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5289     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 9702     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 9698     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5446     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 9696     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5532     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 9704     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5595     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 9700     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 9717     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 9709     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5909     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 9696     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5969     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 9696     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 9701     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6166     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 9685     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 9695     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 9703     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 9719     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 9716     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6633     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 9734     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 9737     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 9743     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6895     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 9741     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6962     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 9751     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 9748     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7162     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 9743     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7217     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 9745     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 9741     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 9743     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7431     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 9748     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 9748     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 9746     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 9751     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 9750     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7876     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 9744     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7959     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 9752     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 9745     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 9755     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 9749     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8304     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 9754     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 9753     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 9766     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8563     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 9768     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 9762     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 9773     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 9788     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 9794     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 9796     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 9787     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 9796     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 9786     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 9794     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9470     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 9790     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 9792     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9635     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 9790     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 9794     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 9786     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 9784     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9930     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 9782     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 4706     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 4727     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10218    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 4750     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 4785     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 4805     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10541    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 4820     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 4830     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 4869     |
# |    time_elapsed     | 2        |
# ...
# |    time_elapsed     | 1115     |
# |    total_timesteps  | 971410   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.168    |
# |    n_updates        | 230352   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 385      |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9304     |
# |    fps              | 870      |
# |    time_elapsed     | 1117     |
# |    total_timesteps  | 973074   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.048    |
# |    n_updates        | 230768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 381      |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9308     |
# |    fps              | 870      |
# |    time_elapsed     | 1118     |
# |    total_timesteps  | 974014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.407    |
# |    n_updates        | 231003   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 379      |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9312     |
# |    fps              | 870      |
# |    time_elapsed     | 1119     |
# |    total_timesteps  | 975261   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.66     |
# |    n_updates        | 231315   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 382      |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9316     |
# |    fps              | 870      |
# |    time_elapsed     | 1121     |
# |    total_timesteps  | 976499   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 231624   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 380      |
# |    ep_rew_mean      | 380      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9320     |
# |    fps              | 870      |
# |    time_elapsed     | 1122     |
# |    total_timesteps  | 977733   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.253    |
# |    n_updates        | 231933   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 367      |
# |    ep_rew_mean      | 367      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9324     |
# |    fps              | 870      |
# |    time_elapsed     | 1123     |
# |    total_timesteps  | 978284   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0347   |
# |    n_updates        | 232070   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 363      |
# |    ep_rew_mean      | 363      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9328     |
# |    fps              | 870      |
# |    time_elapsed     | 1124     |
# |    total_timesteps  | 979459   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72     |
# |    n_updates        | 232364   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 355      |
# |    ep_rew_mean      | 355      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9332     |
# |    fps              | 870      |
# |    time_elapsed     | 1126     |
# |    total_timesteps  | 980386   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.58     |
# |    n_updates        | 232596   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 352      |
# |    ep_rew_mean      | 352      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9336     |
# |    fps              | 870      |
# |    time_elapsed     | 1127     |
# |    total_timesteps  | 981425   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0315   |
# |    n_updates        | 232856   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 342      |
# |    ep_rew_mean      | 342      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9340     |
# |    fps              | 870      |
# |    time_elapsed     | 1128     |
# |    total_timesteps  | 982225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 233056   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 341      |
# |    ep_rew_mean      | 341      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9344     |
# |    fps              | 870      |
# |    time_elapsed     | 1129     |
# |    total_timesteps  | 983382   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 233345   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 329      |
# |    ep_rew_mean      | 329      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9348     |
# |    fps              | 870      |
# |    time_elapsed     | 1130     |
# |    total_timesteps  | 984205   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 233551   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 326      |
# |    ep_rew_mean      | 326      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9352     |
# |    fps              | 870      |
# |    time_elapsed     | 1131     |
# |    total_timesteps  | 984954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 233738   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 322      |
# |    ep_rew_mean      | 322      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9356     |
# |    fps              | 870      |
# |    time_elapsed     | 1132     |
# |    total_timesteps  | 986048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0425   |
# |    n_updates        | 234011   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 315      |
# |    ep_rew_mean      | 315      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9360     |
# |    fps              | 870      |
# |    time_elapsed     | 1133     |
# |    total_timesteps  | 986972   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.25     |
# |    n_updates        | 234242   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 306      |
# |    ep_rew_mean      | 306      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9364     |
# |    fps              | 870      |
# |    time_elapsed     | 1134     |
# |    total_timesteps  | 987670   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 234417   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | 301      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9368     |
# |    fps              | 870      |
# |    time_elapsed     | 1135     |
# |    total_timesteps  | 988498   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.63     |
# |    n_updates        | 234624   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | 296      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9372     |
# |    fps              | 870      |
# |    time_elapsed     | 1136     |
# |    total_timesteps  | 989470   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 234867   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 285      |
# |    ep_rew_mean      | 285      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9376     |
# |    fps              | 870      |
# |    time_elapsed     | 1137     |
# |    total_timesteps  | 990122   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0273   |
# |    n_updates        | 235030   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 276      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9380     |
# |    fps              | 870      |
# |    time_elapsed     | 1138     |
# |    total_timesteps  | 990854   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0336   |
# |    n_updates        | 235213   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 263      |
# |    ep_rew_mean      | 263      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9384     |
# |    fps              | 870      |
# |    time_elapsed     | 1139     |
# |    total_timesteps  | 991630   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 235407   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 257      |
# |    ep_rew_mean      | 257      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9388     |
# |    fps              | 870      |
# |    time_elapsed     | 1140     |
# |    total_timesteps  | 992467   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 235616   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 256      |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9392     |
# |    fps              | 870      |
# |    time_elapsed     | 1141     |
# |    total_timesteps  | 993361   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 235840   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 245      |
# |    ep_rew_mean      | 245      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9396     |
# |    fps              | 870      |
# |    time_elapsed     | 1142     |
# |    total_timesteps  | 994206   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 236051   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 234      |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9400     |
# |    fps              | 870      |
# |    time_elapsed     | 1143     |
# |    total_timesteps  | 994810   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0605   |
# |    n_updates        | 236202   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9404     |
# |    fps              | 870      |
# |    time_elapsed     | 1144     |
# |    total_timesteps  | 995730   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 236432   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9408     |
# |    fps              | 870      |
# |    time_elapsed     | 1145     |
# |    total_timesteps  | 996646   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 236661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 222      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9412     |
# |    fps              | 869      |
# |    time_elapsed     | 1146     |
# |    total_timesteps  | 997435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0139   |
# |    n_updates        | 236858   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9416     |
# |    fps              | 869      |
# |    time_elapsed     | 1147     |
# |    total_timesteps  | 998428   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00882  |
# |    n_updates        | 237106   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9420     |
# |    fps              | 869      |
# |    time_elapsed     | 1148     |
# |    total_timesteps  | 999434   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.856    |
# |    n_updates        | 237358   |
# ----------------------------------

# %%
# save model to file
# model.save("dqn_cartpole")

# load model from file
# model = DQN.load("dqn_cartpole")

# %%
env = gym.make("CartPole-v1", render_mode="human")
# Out:
# Episode #1.

# %%
for episode in range(10):

    print(f"Episode #{episode + 1}.")
    
    obs, _ = env.reset()
    while True:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, _ = env.step(action)
        # print(obs, reward, done)
        env.render()
        if done:
            obs = env.reset()
            break

env.close()

# %%
# Test
